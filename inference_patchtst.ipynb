# %% [markdown]
# <a href="https://colab.research.google.com/github/syunar/PatchTST/blob/dev/inference_patchtst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # git clone

# %%
# %load_ext autoreload
# %autoreload 2
# %cd /content/
email = "dsupa.cs@gmail.com"
username = "syunar"
git_token = "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"
repository = "PatchTST"
branch = "dev"
# !git config --global user.email {email}
# !git config --global user.name {username}
# !git clone https://{git_token}@github.com/{username}/{repository}.git
# %cd $repository
# !git checkout {branch}
import sys
path = f"/content/{repository}"
sys.path.insert(0, path)
sys.path
# Out:
# /content
# Cloning into 'PatchTST'...
# remote: Enumerating objects: 417, done.
# remote: Counting objects: 100% (180/180), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 417 (delta 112), reused 87 (delta 65), pack-reused 237
# Receiving objects: 100% (417/417), 12.94 MiB | 15.86 MiB/s, done.
# Resolving deltas: 100% (197/197), done.
# /content/PatchTST
# Branch 'dev' set up to track remote branch 'dev' from 'origin'.
# Switched to a new branch 'dev'
# ['/content/PatchTST',
#  '/content',
#  '/env/python',
#  '/usr/lib/python310.zip',
#  '/usr/lib/python3.10',
#  '/usr/lib/python3.10/lib-dynload',
#  '',
#  '/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.10/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# %cd PatchTST_supervised
# Out:
# /content/PatchTST/PatchTST_supervised

# %%
# !pip install ipdb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # train

# %%
# !gdown 1alE33S1GmP5wACMXaLu50rDIoVzBM4ik
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1alE33S1GmP5wACMXaLu50rDIoVzBM4ik
# To: /content/PatchTST/PatchTST_supervised/all_six_datasets.zip
# 100% 54.0M/54.0M [00:00<00:00, 74.6MB/s]

# %%
# !unzip -qq all_six_datasets.zip

# %%
import os

os.makedirs("./dataset", exist_ok=True)
# !cp ./all_six_datasets/weather/weather.csv ./dataset/weather.csv

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/PatchTST/PatchTST_supervised/all_six_datasets/weather/weather.csv").set_index("date")
data
# Out:
#                      p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# date
# 2020-01-01 00:10:00   1008.89      0.71    273.18        -1.33    86.1
# 2020-01-01 00:20:00   1008.76      0.75    273.22        -1.44    85.2
# 2020-01-01 00:30:00   1008.66      0.73    273.21        -1.48    85.1
# 2020-01-01 00:40:00   1008.64      0.37    272.86        -1.64    86.3
# 2020-01-01 00:50:00   1008.61      0.33    272.82        -1.50    87.4
# ...                       ...       ...       ...          ...     ...
# 2020-12-31 23:20:00    978.32      2.28    277.16        -0.80    80.0
# 2020-12-31 23:30:00    978.30      2.13    277.01        -0.43    83.1
# 2020-12-31 23:40:00    978.26      1.99    276.88        -0.71    82.2
# 2020-12-31 23:50:00    978.26      2.07    276.95        -0.77    81.4
# 2021-01-01 00:00:00    978.24      2.01    276.89        -0.66    82.4
#
#                      VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# date
# ...

# %%
# !bash ./scripts/PatchTST/weather.sh

# %%
# 336_96_PatchTST_custom_ftM_sl336_ll48_pl96_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0
# mse:0.15138988196849823, mae:0.19924327731132507, rse:0.5125762224197388

# %% [markdown]
# # inference

# %%
# !gdown 1l2uHaz3P-IT-lYEdw5f-XukNmLPSkWdJ
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1l2uHaz3P-IT-lYEdw5f-XukNmLPSkWdJ
# To: /content/PatchTST/PatchTST_supervised/patchtest_checkpoint_weather_for_test_inference.pth
# 100% 3.72M/3.72M [00:00<00:00, 71.4MB/s]

# %%
from models import PatchTST

class Config:

    def __init__(self):
        # basic config
        self.random_seed = 2021  # random seed
        self.is_training = 1  # status
        self.model_id = 'weather'  # model id
        self.model = 'PatchTST'  # model name, options: [Autoformer, Informer, Transformer]

        # data loader
        self.data = 'custom'  # dataset type
        self.root_path = './data/ETT/'  # root path of the data file
        self.data_path = 'weather.csv'  # data file
        self.features = 'M'  # forecasting task, options:[M, S, MS]; M:multivariate predict multivariate, S:univariate predict univariate, MS:multivariate predict univariate
        self.target = 'OT'  # target feature in S or MS task
        self.freq = 'h'  # freq for time features encoding, options:[s:secondly, t:minutely, h:hourly, d:daily, b:business days, w:weekly, m:monthly], you can also use more detailed freq like 15min or 3h
        self.checkpoints = '/content/PatchTST/PatchTST_supervised/patchtest_checkpoint_weather_for_test_inference.pth'  # location of model checkpoints

        # forecasting task
        self.seq_len = 96  # input sequence length
        # self.label_len = 48  # start token length
        self.pred_len = 96  # prediction sequence length

        # DLinear
        # self.individual = False  # DLinear: a linear layer for each variate(channel) individually

        # PatchTST
        self.fc_dropout = 0.05  # fully connected dropout
        self.head_dropout = 0.0  # head dropout
        self.patch_len = 16  # patch length
        self.stride = 8  # stride
        self.padding_patch = 'end'  # None: None; end: padding on the end
        self.revin = 1  # RevIN; True 1 False 0
        self.affine = 0  # RevIN-affine; True 1 False 0
        self.subtract_last = 0  # 0: subtract mean; 1: subtract last
        self.decomposition = 0  # decomposition; True 1 False 0
        self.kernel_size = 25  # decomposition-kernel
        self.individual = 0  # individual head; True 1 False 0

        # Formers
        self.embed_type = 0  # 0: default 1: value embedding + temporal embedding + positional embedding 2: value embedding + temporal embedding 3: value embedding + positional embedding 4: value embedding
        self.enc_in = 7  # encoder input size  # DLinear with --individual, use this hyperparameter as the number of channels
        self.dec_in = 7  # decoder input size
        self.c_out = 7  # output size
        self.d_model = 512  # dimension of model
        self.n_heads = 8  # num of heads
        self.e_layers = 2  # num of encoder layers
        self.d_layers = 1  # num of decoder layers
        self.d_ff = 2048  # dimension of fcn
        self.moving_avg = 25  # window size of moving average
        self.factor = 1  # attn factor
        self.distil = True  # whether to use distilling in encoder, using this argument means not using distilling
        self.dropout = 0.05  # dropout
        self.embed = 'timeF'  # time features encoding, options:[timeF, fixed, learned]
        self.activation = 'gelu'  # activation
        self.output_attention = True  # whether to output attention in ecoder
        self.do_predict = True  # whether to predict unseen future data

        # optimization
        self.num_workers = 10  # data loader num workers
        self.itr = 2  # experiments times
        self.train_epochs = 100  # train epochs
        self.batch_size = 128  # batch size of train input data
        self.patience = 100  # early stopping patience
        self.learning_rate = 0.0001  # optimizer learning rate
        self.des = 'test'  # exp description
        self.loss = 'mse'  # loss function
        self.lradj = 'type3'  # adjust learning rate
        self.pct_start = 0.3  # pct_start
        self.use_amp = False  # use automatic mixed precision training

        # GPU
        self.use_gpu = True  # use gpu
        self.gpu = 0  # gpu
        self.use_multi_gpu = False  # use multiple gpus
        self.devices = '0,1,2,3'  # device ids of multile gpus
        self.test_flop = False  # See utils/tools for usage

    def config(self):
        return self.__dict__

# %%
args = Config()

# %%
args.random_seed = 2021
args.is_training = 1
args.root_path = "./dataset/"
args.data_path = "weather.csv"
args.model = "PatchTST"
args.data = "custom"
args.features = 'M'
args.seq_len = 336
args.label_len = 48
args.pred_len = 96
args.enc_in = 21
args.e_layers = 3
args.n_heads = 16
args.d_model = 128
args.d_ff = 256
args.dropout = 0.2
args.fc_dropout = 0.2
args.head_dropout = 0
args.patch_len = 16
args.stride = 8
args.des = 'Exp'
args.train_epochs = 100
args.patience = 20
args.itr = 1
args.batch_size = 128
args.learning_rate = 0.0001
args.model_id = f"{args.model_id}_{args.seq_len}_{args.pred_len}"

# %%
args.config()
# Out:
# {'random_seed': 2021,
#  'is_training': 1,
#  'model_id': 'weather_336_96',
#  'model': 'PatchTST',
#  'data': 'custom',
#  'root_path': './dataset/',
#  'data_path': 'weather.csv',
#  'features': 'M',
#  'target': 'OT',
#  'freq': 'h',
#  'checkpoints': '/content/PatchTST/PatchTST_supervised/patchtest_checkpoint_weather_for_test_inference.pth',
#  'seq_len': 336,
#  'pred_len': 96,
#  'fc_dropout': 0.2,
#  'head_dropout': 0,
#  'patch_len': 16,
#  'stride': 8,
#  'padding_patch': 'end',
#  'revin': 1,
#  'affine': 0,
#  'subtract_last': 0,
#  'decomposition': 0,
#  'kernel_size': 25,
#  'individual': 0,
#  'embed_type': 0,
#  'enc_in': 21,
#  'dec_in': 7,
#  'c_out': 7,
#  'd_model': 128,
#  'n_heads': 16,
#  'e_layers': 3,
#  'd_layers': 1,
#  'd_ff': 256,
#  'moving_avg': 25,
#  'factor': 1,
#  'distil': True,
#  'dropout': 0.2,
#  'embed': 'timeF',
#  'activation': 'gelu',
#  'output_attention': True,
#  'do_predict': True,
#  'num_workers': 10,
#  'itr': 1,
# ...

# %%
import os
import torch
from exp.exp_main import Exp_Main
import random
import numpy as np

fix_seed = args.random_seed
random.seed(fix_seed)
torch.manual_seed(fix_seed)
np.random.seed(fix_seed)


args.use_gpu = True if torch.cuda.is_available() and args.use_gpu else False

if args.use_gpu and args.use_multi_gpu:
    args.dvices = args.devices.replace(' ', '')
    device_ids = args.devices.split(',')
    args.device_ids = [int(id_) for id_ in device_ids]
    args.gpu = args.device_ids[0]

# %%
args.use_gpu
# Out:
# True

# %%
Exp = Exp_Main

# %%
setting = '{}_{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_fc{}_eb{}_dt{}_{}_{}'.format(
    args.model_id,
    args.model,
    args.data,
    args.features,
    args.seq_len,
    args.label_len,
    args.pred_len,
    args.d_model,
    args.n_heads,
    args.e_layers,
    args.d_layers,
    args.d_ff,
    args.factor,
    args.embed,
    args.distil,
    args.des,
    args.itr)

# %%
setting
# Out:
# 'weather_336_96_PatchTST_custom_ftM_sl336_ll48_pl96_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_1'

# %%
exp = Exp(args)
# Out:
# Use GPU: cuda:0

# %%
exp.predict(setting, load=True)
# Out:
# > /content/PatchTST/PatchTST_supervised/data_provider/data_loader.py(373)__read_data__()
#     372
# --> 373         self.data_x = data[border1:border2]
#     374         if self.inverse:
#
# ipdb> c
# pred 1
# loaded checkpoint
# not loaded checkpoint

# %%
test_ = exp.test(setting)
# Out:
# test 10444
# mse:0.15138988196849823, mae:0.19924327731132507, rse:0.5125762224197388

# %%
import numpy as np

y_pred = np.load("/content/PatchTST/PatchTST_supervised/results/weather_336_96_PatchTST_custom_ftM_sl336_ll48_pl96_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_1/pred.npy")
y_pred.shape
# Out:
# (10368, 96, 21)

# %%
pd.DataFrame(y_pred[0])
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.552678 -0.602958 -0.637318 -0.321871  0.568707 -0.670892 -0.462060
# 1   0.546101 -0.595721 -0.633291 -0.311938  0.609218 -0.665232 -0.453338
# 2   0.542273 -0.596678 -0.634000 -0.299592  0.693065 -0.665960 -0.442124
# 3   0.546623 -0.606186 -0.644494 -0.295042  0.743137 -0.672873 -0.439313
# 4   0.550864 -0.611627 -0.649920 -0.296752  0.725492 -0.677150 -0.437100
# ..       ...       ...       ...       ...       ...       ...       ...
# 91  0.575581 -0.399700 -0.446728 -0.131644  0.545601 -0.515435 -0.284860
# 92  0.565527 -0.389326 -0.435756 -0.126570  0.565881 -0.507129 -0.282185
# 93  0.559703 -0.379423 -0.424272 -0.124942  0.554530 -0.499773 -0.281335
# 94  0.563653 -0.363041 -0.407569 -0.153579  0.427148 -0.486758 -0.304721
# 95  0.548523 -0.342482 -0.387513 -0.143214  0.454079 -0.469847 -0.299725
#
#           7         8         9   ...        11        12        13        14  \
# ...

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

pd.DataFrame(test_.inverse_transform(pd.DataFrame(y_pred[0])))[20]
# Out:
# 0     423.491028
# 1     423.817719
# 2     425.425659
# 3     425.784912
# 4     426.383484
#          ...
# 91    421.076447
# 92    419.945343
# 93    419.775360
# 94    418.437683
# 95    417.180298
# Name: 20, Length: 96, dtype: float32

# %%
data
# Out:
# array([[ 2.05285544, -1.35343185, -1.52514843, ..., -0.54145312,
#         -1.29197696,  0.03203496],
#        [ 2.03873584, -1.34807609, -1.51989697, ..., -0.54145312,
#         -1.28427532,  0.03172398],
#        [ 2.02787462, -1.35075397, -1.52120984, ..., -0.54145312,
#         -1.27272285,  0.03048008],
#        ...,
#        [-1.27393869, -1.18204765, -1.03938795, ..., -0.54145312,
#         -1.03525553,  0.05411434],
#        [-1.27393869, -1.17133613, -1.03019789, ..., -0.54145312,
#         -1.03268832,  0.05007164],
#        [-1.27611094, -1.17936977, -1.03807508, ..., -0.54145312,
#         -1.03140471,  0.05815705]])

# %%
for seq_x, seq_y, seq_x_mark, seq_y_mark in pred_loader:
    print(seq_x.shape, seq_y.shape, seq_x_mark.shape, seq_y_mark.shape)
# Out:
# torch.Size([1, 336, 21]) torch.Size([1, 48, 21]) torch.Size([1, 336, 4]) torch.Size([1, 144, 4])

# %%
seq_y[0]
# Out:
# tensor([[-1.3348, -1.0066, -0.8608,  ..., -0.4991, -0.9942,  0.0274],
#         [-1.3315, -1.0066, -0.8608,  ..., -0.5121, -0.9967,  0.0277],
#         [-1.3304, -1.0040, -0.8582,  ..., -0.5309, -0.9980,  0.0289],
#         ...,
#         [-1.2739, -1.1820, -1.0394,  ..., -0.5415, -1.0353,  0.0541],
#         [-1.2739, -1.1713, -1.0302,  ..., -0.5415, -1.0327,  0.0501],
#         [-1.2761, -1.1794, -1.0381,  ..., -0.5415, -1.0314,  0.0582]],
#        dtype=torch.float64)

# %%
144 - 48
# Out:
# 96

# %%
data
# Out:
#                      p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# date
# 2020-01-01 00:10:00   1008.89      0.71    273.18        -1.33    86.1
# 2020-01-01 00:20:00   1008.76      0.75    273.22        -1.44    85.2
# 2020-01-01 00:30:00   1008.66      0.73    273.21        -1.48    85.1
# 2020-01-01 00:40:00   1008.64      0.37    272.86        -1.64    86.3
# 2020-01-01 00:50:00   1008.61      0.33    272.82        -1.50    87.4
# ...                       ...       ...       ...          ...     ...
# 2020-12-31 23:20:00    978.32      2.28    277.16        -0.80    80.0
# 2020-12-31 23:30:00    978.30      2.13    277.01        -0.43    83.1
# 2020-12-31 23:40:00    978.26      1.99    276.88        -0.71    82.2
# 2020-12-31 23:50:00    978.26      2.07    276.95        -0.77    81.4
# 2021-01-01 00:00:00    978.24      2.01    276.89        -0.66    82.4
#
#                      VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# date
# ...

# %%
from utils.timefeatures import time_features
from sklearn.preprocessing import StandardScaler
import ipdb

target = 'OT'
features = 'M'
scale = True
pred_len = 96
seq_len = 336
freq = 'h'
timeenc = 1
inverse = False

scaler = StandardScaler()
df_raw = pd.read_csv("/content/PatchTST/PatchTST_supervised/dataset/weather.csv")
'''
df_raw.columns: ['date', ...(other features), target feature]
'''

cols = list(df_raw.columns)
cols.remove(target)
cols.remove('date')

df_raw = df_raw[['date'] + cols + [target]]
border1 = len(df_raw) - seq_len
border2 = len(df_raw)

if features == 'M' or features == 'MS':
    cols_data = df_raw.columns[1:]
    df_data = df_raw[cols_data]
elif features == 'S':
    df_data = df_raw[[target]]

if scale:
    scaler.fit(df_data.values)
    data = scaler.transform(df_data.values)
else:
    data = df_data.values

tmp_stamp = df_raw[['date']][border1:border2]
tmp_stamp['date'] = pd.to_datetime(tmp_stamp.date)
pred_dates = pd.date_range(tmp_stamp.date.values[-1], periods=pred_len + 1, freq=freq)

df_stamp = pd.DataFrame(columns=['date'])
df_stamp.date = list(tmp_stamp.date.values) + list(pred_dates[1:])
if timeenc == 0:
    df_stamp['month'] = df_stamp.date.apply(lambda row: row.month, 1)
    df_stamp['day'] = df_stamp.date.apply(lambda row: row.day, 1)
    df_stamp['weekday'] = df_stamp.date.apply(lambda row: row.weekday(), 1)
    df_stamp['hour'] = df_stamp.date.apply(lambda row: row.hour, 1)
    df_stamp['minute'] = df_stamp.date.apply(lambda row: row.minute, 1)
    df_stamp['minute'] = df_stamp.minute.map(lambda x: x // 15)
    data_stamp = df_stamp.drop(['date'], axis=1).values
elif timeenc == 1:
    data_stamp = time_features(pd.to_datetime(df_stamp['date'].values), freq=freq)
    data_stamp = data_stamp.transpose(1, 0)

# ipdb.set_trace()

data_x = data[border1:border2]
if inverse:
    data_y = df_data.values[border1:border2]
else:
    data_y = data[border1:border2]
# Out:
# --Return--
# None
# > <ipython-input-38-b0a2dd4ab377>(58)<cell line: 58>()
#      57
# ---> 58 ipdb.set_trace()
#      59
#
# ipdb> c

# %%
'TST' in args.model
# Out:
# True

# %%
data_y.shape
# Out:
# (336, 21)

# %%
tmp_stamp
# Out:
#                      date
# 52360 2020-12-29 16:10:00
# 52361 2020-12-29 16:20:00
# 52362 2020-12-29 16:30:00
# 52363 2020-12-29 16:40:00
# 52364 2020-12-29 16:50:00
# ...                   ...
# 52691 2020-12-31 23:20:00
# 52692 2020-12-31 23:30:00
# 52693 2020-12-31 23:40:00
# 52694 2020-12-31 23:50:00
# 52695 2021-01-01 00:00:00
#
# [336 rows x 1 columns]

# %%
df_stamp
# Out:
#                    date
# 0   2020-12-29 16:10:00
# 1   2020-12-29 16:20:00
# 2   2020-12-29 16:30:00
# 3   2020-12-29 16:40:00
# 4   2020-12-29 16:50:00
# ..                  ...
# 427 2021-01-04 20:00:00
# 428 2021-01-04 21:00:00
# 429 2021-01-04 22:00:00
# 430 2021-01-04 23:00:00
# 431 2021-01-05 00:00:00
#
# [432 rows x 1 columns]

# %%
432 - 336
# Out:
# 96

# %%
data_stamp.shape
# Out:
# (432, 4)

# %%
len(pred_data[0])
# Out:
# 4

# %%
data.shape
# Out:
# (52696, 21)

# %%
for i in range(len(pred_data[0])):
    print(pred_data[0][i].shape)
# Out:
# (336, 21)
# (48, 21)
# (336, 4)
# (144, 4)

# %%
pred_data[0][3]
# Out:
# array([[ 0.19565217,  0.        ,  0.5       ,  0.5       ],
#        [ 0.19565217,  0.        ,  0.5       ,  0.5       ],
#        [ 0.19565217,  0.        ,  0.5       ,  0.5       ],
#        [ 0.19565217,  0.        ,  0.5       ,  0.5       ],
#        [ 0.19565217,  0.        ,  0.5       ,  0.5       ],
#        [ 0.23913043,  0.        ,  0.5       ,  0.5       ],
#        [ 0.23913043,  0.        ,  0.5       ,  0.5       ],
#        [ 0.23913043,  0.        ,  0.5       ,  0.5       ],
#        [ 0.23913043,  0.        ,  0.5       ,  0.5       ],
#        [ 0.23913043,  0.        ,  0.5       ,  0.5       ],
#        [ 0.23913043,  0.        ,  0.5       ,  0.5       ],
#        [ 0.2826087 ,  0.        ,  0.5       ,  0.5       ],
#        [ 0.2826087 ,  0.        ,  0.5       ,  0.5       ],
#        [ 0.2826087 ,  0.        ,  0.5       ,  0.5       ],
#        [ 0.2826087 ,  0.        ,  0.5       ,  0.5       ],
# ...

# %%
import os
import numpy as np
import pandas as pd
import os
import torch
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler
from utils.timefeatures import time_features
import warnings

warnings.filterwarnings('ignore')

import ipdb

class Dataset_Pred(Dataset):
    def __init__(self, root_path, flag='pred', size=None,
                 features='S', data_path='ETTh1.csv',
                 target='OT', scale=True, inverse=False, timeenc=0, freq='15min', cols=None):
        # size [seq_len, label_len, pred_len]
        # info
        if size == None:
            self.seq_len = 24 * 4 * 4
            self.label_len = 24 * 4
            self.pred_len = 24 * 4
        else:
            self.seq_len = size[0]
            self.label_len = size[1]
            self.pred_len = size[2]
        # init
        assert flag in ['pred']

        self.features = features
        self.target = target
        self.scale = scale
        self.inverse = inverse
        self.timeenc = timeenc
        self.freq = freq
        self.cols = cols
        self.root_path = root_path
        self.data_path = data_path
        self.__read_data__()

    def __read_data__(self):
        self.scaler = StandardScaler()
        df_raw = pd.read_csv(os.path.join(self.root_path,
                                          self.data_path))
        '''
        df_raw.columns: ['date', ...(other features), target feature]
        '''
        if self.cols:
            cols = self.cols.copy()
            cols.remove(self.target)
        else:
            cols = list(df_raw.columns)
            cols.remove(self.target)
            cols.remove('date')
        df_raw = df_raw[['date'] + cols + [self.target]]
        border1 = len(df_raw) - self.seq_len
        border2 = len(df_raw)

        if self.features == 'M' or self.features == 'MS':
            cols_data = df_raw.columns[1:]
            df_data = df_raw[cols_data]
        elif self.features == 'S':
            df_data = df_raw[[self.target]]

        if self.scale:
            self.scaler.fit(df_data.values)
            data = self.scaler.transform(df_data.values)
        else:
            data = df_data.values

        tmp_stamp = df_raw[['date']][border1:border2]
        tmp_stamp['date'] = pd.to_datetime(tmp_stamp.date)
        pred_dates = pd.date_range(tmp_stamp.date.values[-1], periods=self.pred_len + 1, freq=self.freq)

        df_stamp = pd.DataFrame(columns=['date'])
        df_stamp.date = list(tmp_stamp.date.values) + list(pred_dates[1:])
        print(self.timeenc)
        if self.timeenc == 0:
            df_stamp['month'] = df_stamp.date.apply(lambda row: row.month, 1)
            df_stamp['day'] = df_stamp.date.apply(lambda row: row.day, 1)
            df_stamp['weekday'] = df_stamp.date.apply(lambda row: row.weekday(), 1)
            df_stamp['hour'] = df_stamp.date.apply(lambda row: row.hour, 1)
            df_stamp['minute'] = df_stamp.date.apply(lambda row: row.minute, 1)
            df_stamp['minute'] = df_stamp.minute.map(lambda x: x // 15)
            # data_stamp = df_stamp.drop(['date'], axis=1).values
            data_stamp = df_stamp.values
        elif self.timeenc == 1:
            data_stamp = time_features(pd.to_datetime(df_stamp['date'].values), freq=self.freq)
            ipdb.set_trace()
            data_stamp = data_stamp.transpose(1, 0)

        self.data_x = data[border1:border2]
        print(self.inverse)
        if self.inverse:
            self.data_y = df_data.values[border1:border2]
        else:
            self.data_y = data[border1:border2]
        self.data_stamp = data_stamp

        print(data_stamp)

    def __getitem__(self, index):
        s_begin = index
        s_end = s_begin + self.seq_len
        r_begin = s_end - self.label_len
        r_end = r_begin + self.label_len + self.pred_len

        seq_x = self.data_x[s_begin:s_end]
        print(self.inverse)
        if self.inverse:
            seq_y = self.data_x[r_begin:r_begin + self.label_len]
        else:
            seq_y = self.data_y[r_begin:r_begin + self.label_len]
        seq_x_mark = self.data_stamp[s_begin:s_end]
        seq_y_mark = self.data_stamp[r_begin:r_end]

        return seq_x, seq_y, seq_x_mark, seq_y_mark

    def __len__(self):
        return len(self.data_x) - self.seq_len + 1

    def inverse_transform(self, data):
        return self.scaler.inverse_transform(data)

# %%
import pandas as pd

# Assuming df_stamp is a DataFrame with a 'date' column containing date-like strings
df_stamp = pd.DataFrame({'date': ['2023-09-19', '2023-09-20', '2023-09-21']})

# Mockup function for time_features (since it's not defined)
def time_features(dates, freq):
    # For this mockup, let's assume it returns a list of extracted features
    return [f'Feature_{i}' for i in range(len(dates))]

# Assuming self.freq is a variable with a frequency value (e.g., 'D' for daily)
self_freq = 'D'

# Applying the code
data_stamp = time_features(pd.to_datetime(df_stamp['date'].values), freq=self_freq)

# Printing the result
print(data_stamp)
# Out:
# ['Feature_0', 'Feature_1', 'Feature_2']

# %%
timeenc = 1

flag = 'pred'
shuffle_flag = False
drop_last = False
batch_size = 1
freq = args.freq
Data = Dataset_Pred

data_set = Data(
    root_path=args.root_path,
    data_path=args.data_path,
    flag=flag,
    size=[args.seq_len, args.label_len, args.pred_len],
    features=args.features,
    target=args.target,
    timeenc=timeenc,
    freq=freq
)
# Out:
# 1
# > <ipython-input-82-e66922905d0d>(92)__read_data__()
#      91             ipdb.set_trace()
# ---> 92             data_stamp = data_stamp.transpose(1, 0)
#      93
#
# ipdb> data_stamp
# array([[ 0.19565217,  0.19565217,  0.19565217, ...,  0.45652174,
#          0.5       , -0.5       ],
#        [-0.33333333, -0.33333333, -0.33333333, ..., -0.5       ,
#         -0.5       , -0.33333333],
#        [ 0.43333333,  0.43333333,  0.43333333, ..., -0.4       ,
#         -0.4       , -0.36666667],
#        [ 0.49452055,  0.49452055,  0.49452055, ..., -0.49178082,
#         -0.49178082, -0.4890411 ]])
# ipdb> data_stamp.shape
# (4, 432)
# ipdb> df_stamp
#                    date
# 0   2020-12-29 16:10:00
# 1   2020-12-29 16:20:00
# 2   2020-12-29 16:30:00
# 3   2020-12-29 16:40:00
# 4   2020-12-29 16:50:00
# ..                  ...
# 427 2021-01-04 20:00:00
# 428 2021-01-04 21:00:00
# 429 2021-01-04 22:00:00
# 430 2021-01-04 23:00:00
# 431 2021-01-05 00:00:00
#
# [432 rows x 1 columns]
# ...

# %%
len(data_set)
# Out:
# 1

# %%
data.loc['2020-12-29':].iloc[:336]
# Out:
#                      p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# date
# 2020-12-29 00:00:00    956.11      0.29    276.98         0.29   100.0
# 2020-12-29 00:10:00    956.23      0.29    276.96         0.29   100.0
# 2020-12-29 00:20:00    956.46      0.14    276.79         0.14   100.0
# 2020-12-29 00:30:00    956.55      0.06    276.70         0.06   100.0
# 2020-12-29 00:40:00    956.62      0.01    276.65         0.01   100.0
# ...                       ...       ...       ...          ...     ...
# 2020-12-31 07:10:00    980.00      0.72    275.46        -0.86    89.1
# 2020-12-31 07:20:00    980.12      0.44    275.17        -0.92    90.5
# 2020-12-31 07:30:00    980.23      0.15    274.87        -1.03    91.7
# 2020-12-31 07:40:00    980.27      0.04    274.76        -1.02    92.5
# 2020-12-31 07:50:00    980.35     -0.07    274.64        -1.04    93.1
#
#                      VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# date
# ...

# %%
data_set[0]
# Out:
# False
# (array([[-2.50886031, -1.0160192 , -0.75318312, ..., -0.50390606,
#          -1.13152607,  0.0273703 ],
#         [-2.49908521, -1.02539177, -0.76368605, ..., -0.51731071,
#          -1.13280968,  0.02830323],
#         [-2.47627663, -1.05350949, -0.79388197, ..., -0.53078554,
#          -1.1379441 ,  0.02457151],
#         ...,
#         [-1.27393869, -1.18204765, -1.03938795, ..., -0.54145312,
#          -1.03525553,  0.05411434],
#         [-1.27393869, -1.17133613, -1.03019789, ..., -0.54145312,
#          -1.03268832,  0.05007164],
#         [-1.27611094, -1.17936977, -1.03807508, ..., -0.54145312,
#          -1.03140471,  0.05815705]]),
#  array([[-1.33476157, -1.00664663, -0.86083815, ..., -0.49908108,
#          -0.99418011,  0.0273703 ],
#         [-1.3315032 , -1.00664663, -0.86083815, ..., -0.51213483,
#          -0.99674732,  0.02768128],
#         [-1.33041708, -1.00396875, -0.85821242, ..., -0.53094345,
#          -0.99803093,  0.02892519],
#         ...,
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 10 (delta 6), reused 8 (delta 4), pack-reused 0
# Unpacking objects: 100% (10/10), 852 bytes | 284.00 KiB/s, done.
# From https://github.com/syunar/PatchTST
#    ac6f334..87155fd  dev        -> origin/dev
# Updating ac6f334..87155fd
# Fast-forward
#  PatchTST_supervised/exp/exp_main.py | 2 ++
#  1 file changed, 2 insertions(+)
